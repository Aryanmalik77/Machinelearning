# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression

# %%
X,y = make_regression(n_samples = 100,n_informative = 2, n_targets = 2, n_features =2, noise = 12, random_state = 42)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size = 0.25, random_state = 42)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X,y,"b.")

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([[-175.83797968, -168.5282969 ],
#        [ -15.05883673,   -8.73012721],
#        [ 175.25387177,  177.74676142],
#        [  93.46305059,   77.33400013],
#        [ -12.61552944,  -23.64397668],
#        [ 102.07073473,  103.27779053],
#        [  28.2435385 ,   38.49374518],
#        [ -11.49536578,  -14.00554844],
#        [ 202.19398273,  196.46001657],
#        [ 137.90480247,  135.94010853],
#        [-185.80449595, -171.51581926],
#        [ 161.5715284 ,  156.85529846],
#        [  37.29584122,   31.4975646 ],
#        [ -83.01028012,  -82.29380186],
#        [  34.84205339,   28.70779072],
#        [-122.73575926, -115.44588686],
#        [ -34.76007589,  -34.10066886],
#        [ 176.10180151,  157.27634631],
#        [  81.94430014,   79.56425054],
#        [  76.88694189,   68.98319517],
#        [  96.80603418,   94.16141294],
#        [  -9.10116743,   -4.34270349],
#        [  76.34183329,   84.08677725],
#        [ -92.08771448,  -85.79664236],
# ...

# %%
from sklearn.linear_model import Lasso

# %%
ls = Lasso(alpha = 100)

# %%
ls.fit(X_train, Y_train)
# Out:
# Lasso(alpha=100)

# %%
y_pred = ls.predict(X_test)

# %%
from sklearn.metrics  import r2_score

# %%
r2_score(Y_test,y_pred)
# Out:
# coef_

# %%
class meralasso:
    def __init__(self,alpha):
        self.alpha = alpha
        self.intercept_ = None
        self.coef_ = None

    def fit(self,X_train,Y_train):
        den = 0
        num = 0
        for i in range(X_train.shape[0]):
            num = num + (Y_train[i] - Y_train.mean())*(X_train[i] - X_train.mean())
            den = den + (X_train[i] - X_train.mean())* (X_train[i] - X_train.mean())
            self.intercept_ = (num -self.alpha)/den
            self.coef_ = Y_train.mean() - (self.intercept_ *X_train.mean())
        print(self.intercept_,self.coef_)

    def predict(X_test):
        pass

# %%
las = meralasso(alpha = 100)

# %%
las.fit(X_train,Y_train)
# Out:
# [81.41283248 65.9625643 ] [-7.02206133 -8.66319608]
