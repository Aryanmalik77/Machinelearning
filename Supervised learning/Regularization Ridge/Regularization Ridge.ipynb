# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression

# %%
x,y =make_regression(n_samples = 100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train, Y_test = train_test_split(x,y,test_size = 0.25, random_state = 42)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y,"b.")

# %%
from sklearn.linear_model import Ridge

# %%
rg = Ridge(alpha = 0.01)

# %%
rg.fit(X_train,Y_train)
# Out:
# Ridge(alpha=0.01)

# %%
y_pred= rg.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.649967411268288

# %%
# Now from scratch

# %%
class MeraRidge:
    def __init__(self,alpha):
        self.intercept_= None
        self.coef_ = None
        self.alpha = alpha
    def fit(self,X_train,Y_train):
        num = 0
        den = 0
        for i in range(X_train.shape[0]):
            num = num + (Y_train[i] - Y_train.mean())*(X_train[i] - X_train)
            den = den +(X_train[i] - X_train.mean())*(X_train[i] - X_train.mean()) 
             
            self.m = num/(den + self.alpha)
            self.b = Y_train.mean() - (self.m*X_train.mean())
        print(self.m,self.b)

    def predict(X_test):
       pass

# %%
rdg = MeraRidge(alpha = 100)

# %%
rdg.fit(X_train, Y_train)
# Out:
# [[11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]
#  [11.31795276]] [[-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]
#  [-2.04577202]]

# %%
plt.plot(x,y,"b.")
plt.plot(X_train,rg.predict(X_train),color = "r")
